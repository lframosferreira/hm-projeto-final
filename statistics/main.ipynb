# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../grid_search_ga.csv", index_col=0)
df.plot()
# Out:
# <Axes: >

# %%
df = pd.read_csv("../heuristica_controle.csv", index_col=0)
plt.figure(figsize = (14,6))
for f in df["graph_file_pretty"].unique():
    plt.plot(df[df["graph_file_pretty"]==f]["cur_clique"])
plt.xlabel("Execution time (s)")
plt.ylabel("Size of clique")
plt.title("Heuristica controle")
plt.legend()
# Out:
# /tmp/ipykernel_85960/1301055305.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
